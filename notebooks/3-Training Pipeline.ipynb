# %%
# Import the Feature Generartor
import feature_generator

# %%
# Instantiate the Feature Generator Class
feature_generator_ = feature_generator.feature_creator(fpath_data_input='data/synthetic_txn_data.csv')

# %%
# Get stratified Train/Test Data
X_train, X_test, y_train, y_test = feature_generator_.get_data_for_training()

# %%
X_train.head()
# Out:
#      Feature0  Feature1  Feature2  Feature3  Feature4  Feature5  Feature6  \
# 466 -0.061607  0.021109 -0.029507  0.050608  0.001134  0.005973  0.040485
# 129 -0.025332 -0.051232 -0.100755  0.055770 -0.009053 -0.016233  0.007624
# 940 -0.013159 -0.021021  0.007008 -0.022461  0.002843  0.021604  0.028168
# 730 -0.014338  0.036519 -0.030587 -0.043091 -0.097023  0.038005 -0.047036
# 210  0.020997 -0.052240 -0.077261 -0.066575  0.055326  0.087589 -0.029689
#
#      Feature7  Feature8  Feature9  ...  Feature375  Feature376  Feature377  \
# 466  0.028323 -0.034021  0.046917  ...    0.055946   -0.067546   -0.101885
# 129  0.025452 -0.021775 -0.015170  ...    0.064789   -0.051988   -0.059050
# 940  0.084881 -0.046810 -0.008587  ...    0.019474   -0.091984   -0.030931
# 730 -0.017092 -0.057033  0.007419  ...    0.151159   -0.095012   -0.085966
# 210  0.046233 -0.017779 -0.011467  ...    0.066864   -0.018092   -0.051249
#
# ...

# %%
import trainer

# %%
# Specify the path to the synthetic data
feature_generator_ = feature_generator.feature_creator(fpath_data_input='data/synthetic_txn_data.csv')
# Pass the feature creator to the trainer and train the model
task = trainer.Trainer(feature_creator = feature_generator_)
# Call to train the model and save assests to the fpath_output
task.train()
